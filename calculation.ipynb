# %% [markdown]
# ### 3 вариант

# %% [markdown]
# Уравнение поперечных колебаний стержня имеет вид:
#
# $$EI\frac{\partial ^4 y(x, t)}{\partial x^4} + P\frac{\partial ^2 y(x, t)}{\partial x^2} + m\frac{\partial ^2 y(x, t)}{\partial t^2} = 0$$
#
# где EI - изгибная жёсткость стержня, m - распределённая масса, P - сжимающая нагрузка.
#
# Один конец стержня закреплён жёстко, а другой шарнирно (l - длина стержня):
#
# $$y(x, t) \bigg|_{x=0} = 0 ; \frac{dy(x, t)}{dx} \bigg|_{x=0} = 0$$
# $$y(x, t) \bigg|_{x=l} = 0;  \frac{d ^2 y(x, t)}{dx^2} \bigg|_{x=l} = 0$$

# %% [markdown]
# #### 1.1. Проверка операторов на самосопряжённость:

# %% [markdown]
# - A = m, очевидно самосопряженный, так как
#
#
# $ \int\limits_0^l U_imU_jdx - \int\limits_0^l U_jmU_idx = 0 $
#
# - B = 0 - самосопряженный
#
# - $C = \frac{\partial ^4 y(x, t)}{\partial x^4}EI + P\frac{\partial ^2 y(x, t)}{\partial x^2}$
#
# Получаем сумму двух интегралов:
#
# $ \int\limits_0^l U_iCU_jdx - \int\limits_0^l U_jCU_idx = EI\int\limits_0^l (U_iU_j''''-U_i''''U_j)dx + P\int\limits_0^l (U_iU_j''-U_i''U_j)dx $
#
# Промежуточные вычисления:
#
# ---
#
# $ \int\limits_0^l U_iU_j''''dx = U_iU_j'''\bigg|_0^l - \int\limits_0^l U_i'U_j'''dx = (U_iU_j''' - U_i'U_j'')\bigg|_0^l + \int\limits_0^l U_i''U_j''dx $
#
# $ \int\limits_0^l U_iU_j''dx = U_iU_j\bigg|_0^l - \int\limits_0^l U_i'U_j'dx $
#
# ---
#
# 1. $ (U_iU_j'''-U_i'U_j''+U_i''U_j' - U_i'''U_j)\bigg|_0^l = (0U_j'''-U_i'0+0U_j' - U_i'''0) - (0U_j'''-0U_j''+U_i''0 - U_i'''0) = 0 $
#
# 2. $ (U_iU_j'-U_i'U_j)\bigg|_0^l = (0U_j'-U_i'0) - (00-00) = 0 $
#
# Следовательно, оператор C - самосопряжённый

# %% [markdown]
# #### 1.2 Проверка операторов на положительную определенность

# %% [markdown]
#  - A = m
#
#
# $ \int\limits_0^l UmUdx =  m\int\limits_0^l U^2dx >= 0 $
#
# Положительно определенный.
#
# - B = 0 - неотрицательно определенный
#
# $ \int\limits_0^l U0Udx = 0 $
#
# - $C = \frac{\partial ^4 y(x, t)}{\partial x^4}EI + P\frac{\partial ^2 y(x, t)}{\partial x^2}$
#
# $ \int\limits_0^l U(EI*U'''' P*U'')dx = EI*(UU'''\bigg|_0^l - U'U''\bigg|_0^l + \int\limits_0^l (U'')^2 dx) + P (UU'\bigg|_0^l - \int\limits_0^l(U')^2dx)) = EI \int\limits_0^l (U'')^2dx - P \int\limits_0^l (U')^2dx $
#
# Невозможно что-либо сказать о положительной определенности, поэтому оператор не положительно определенный.

# %% [markdown]
# #### 2. При отсутствии сжимающей нагрузки и заданных граничных условиях поставить задачу нахождения собственных значений и собственных форм деформации. Найти три первых собственных значения и соответствующие им формы деформации.

# %% [markdown]
# $$ EI\frac{\partial ^4 y(x, t)}{\partial x^4} + m\frac{\partial ^2 y(x, t)}{\partial t^2} = 0; P = 0 $$
#
# $ Пусть \ x = \varphi l \ , \ 0 \leq \varphi \leq l \ , \ t = \tau T \ - \ безразмерные \ переменные $
#
# Уравнение примет вид:
#
# $ \large \frac{EI}{l^4}\frac{\partial ^4 y(\varphi, \tau)}{\partial \varphi^4} + \frac{m}{T^2}\frac{\partial ^2 y(\varphi, \tau)}{\partial \tau^2} = 0 $
#
# $ \normalsize \frac{\partial ^4 y(\varphi, \tau)}{\partial \varphi^4} + \frac{ml^4}{EIT^2}\frac{\partial ^2 y(\varphi, \tau)}{\partial \tau^2} = 0, \ где \ \frac{ml^4}{EIT^2} = 1, \ так \ как \ T = l^2\sqrt{\frac{m}{EI}} $
#
# $ \large \frac{\partial ^4 y(\varphi, \tau)}{\partial \varphi^4} + \frac{\partial ^2 y(\varphi, \tau)}{\partial \tau^2} = 0 $
#
# $ y(\varphi, \tau) = Y(\varphi)T(\tau) $
#
# $ \normalsize Y''''T + YT'' = 0 \ / \ :YT $
#
# Так как $\varphi \ и \ \tau$ - независимые переменные, то равенство возможно только если обе дроби равны константе
#
# $ \large \frac{Y''''}{Y} = -\frac{T''}{T} = \lambda $
#
# $
#  \begin{cases}
#    Y'''' - \lambda Y = 0,
#    \\
#    T'' + \lambda T = 0.
#  \end{cases}
# $

# %% [markdown]
# **Проблема собственных значений и граничные условия:**
#
# $$ Y'''' - \lambda Y = 0 $$
# $$ Y\bigg|_{\varphi=0} = 0 ; \ \frac{\partial Y}{\partial \varphi}\bigg|_{\varphi=0} = 0; \ Y\bigg|_{\varphi=1} = 0;  \ \frac{\partial ^2 Y}{\partial \varphi^2} \bigg|_{\varphi=1} = 0$$
#
# $Пусть \ \lambda = \beta^4 \ ; \ Y = e^{ik\varphi}, \ тогда \ характеристическое \ уравнение \ и \ его \ корни \ будут \ иметь \ вид:$
#
# $ k^4 - \beta = 0; \\ k_{1,2} = \pm\beta \ ; \ k_{3,4} = \pm i\beta$
#
# Тогда уравнение примет вид:
#
# $Y = C_1\sin{\beta\varphi} + C_2\cos{\beta\varphi} + C_3\sinh{\beta\varphi} + C_4\cosh{\beta\varphi}$
#
# $Y' =  \beta(C_1\cos{\beta\varphi} - C_2\sin{\beta\varphi} + C_3\cosh{\beta\varphi} + C_4\sinh{\beta\varphi})$
#
# $Y'' = \beta^2(-C_1\sin{\beta\varphi} - C_2\cos{\beta\varphi} + C_3\sinh{\beta\varphi} + C_4\cosh{\beta\varphi}) $
#
# Ищем $C_{1,2,3,4}$ из граничных условий:
#
# $
#  \begin{cases}
#    C_2 + C_4 = 0,
#    \\
#    C_1 + C_3 = 0,
#    \\
#    -C_3\sin{\beta} - C_4\cos{\beta} + C_3\sinh{\beta} + C_4\cosh{\beta} = 0,
#    \\
#    C_3\sin{\beta} + C_4\cos{\beta} + C_3\sinh{\beta} + C_4\cosh{\beta} = 0.
#  \end{cases}
# $
#
# $
#  \begin{cases}
#    C_2 = -C_4,
#    \\
#    C_1 = -C_3,
#    \\
#    C_3\sinh{\beta} + C_4\cosh{\beta} = 0,
#    \\
#    C_3\sin{\beta} + C_4\cos{\beta} = 0.
#  \end{cases}
# $
#
# $ \large  \Rightarrow \frac{C_3}{C_4} = \tan{\beta} = \tan{\beta} $
#
# $
# \begin{cases}
# C_1 = -\tan{\beta} \tilde C = -\tanh{\beta}\tilde C
# \\
# C_2 = \tilde C
# \\
# C_3 = \tan{\beta} \tilde C = \tanh{\beta}\tilde C
# \\
# C_4 = - \tilde C
# \end{cases}
# $
#
# $ \normalsize Y = \tilde C(- \tan{\beta}\sin{\beta\varphi} + \cos{\beta\varphi} + \tanh{\beta}\sinh{\beta\varphi} - \cosh{\beta\varphi}) = \\ = \frac{\tilde C}{\cos{\beta}}(-\sin{\beta}\sin{\beta\varphi} + \cos{\beta}\cos{\beta\varphi}) - \frac{\tilde C}{\cosh{\beta}}(\cosh{\beta}\cosh{\beta\varphi} - \sinh{\beta}\sinh{\beta\varphi}) = \\ = \frac{\tilde C}{2\cos{\beta}}(\cos{\beta(\varphi-1)} + \cos{\beta(\varphi+1)} - \cos{\beta(\varphi-1)} + \cos{\beta(\varphi+1)}) - \\ - \frac{\tilde C}{2\cosh{\beta}}(\cosh{\beta(\varphi+1)} + \cosh{\beta(\varphi-1)} - \cosh{\beta(\varphi+1)} + \cosh{\beta(\varphi-1)}) = \frac{\tilde C}{\cos{\beta}}\cos{\beta(\varphi+1)} - \frac{\tilde C}{\cosh{\beta}}\cosh{\beta(\varphi-1)}$
#
# **Получаем:**
#
# $ \large Y = \frac{\tilde C}{\cos{\beta}}\cos{\beta(\varphi+1)} - \frac{\tilde C}{\cosh{\beta}}\cosh{\beta(\varphi-1)}$

# %% [markdown]
# Проведём нормировку, исходя из условий: $ \int\limits_0^1 Y_н ^ 2d\varphi = 1$
#
# $ \normalsize \int\limits_0^1 Y_н ^ 2d\varphi = \frac{\tilde C^2}{\cos^2{\beta}} \int\limits_0^1 \cos^2{\beta(\varphi+1)} d\varphi + \frac{\tilde C^2}{\cosh^2{\beta}} \int\limits_0^1 \cosh^2{\beta(\varphi-1)} d\varphi - \frac{2\tilde C^2}{\cos{\beta}\cosh{\beta}} \int\limits_0^1 \cosh{\beta(\varphi-1)}\cos{\beta(\varphi+1)} d\varphi$
#
# Получаем сумму трёх интегралов, $ I_{1, 2, 3} $ соответственно:
#
# - $ \normalsize I_1 = \frac{1}{2} \int\limits_0^1 (1 + \cos{2\beta(\varphi+1)}) d\varphi = (\frac{\varphi}{2} + \frac{\sin{2\beta(\varphi+1)}}{4\beta})\big|_0^1 = \frac{1}{2} + \frac{1}{2\beta}\sin{\beta}\cos{3\beta}$
#
# - $ \normalsize I_2 = \frac{1}{2} + \frac{1}{2\beta}\sinh{\beta}\cosh{\beta}$ - Аналогично
#
# - $ \normalsize I_3 = \int\limits_0^1 \cosh{\beta(\varphi-1)}\cos{\beta(\varphi+1)} d\varphi = \frac{1}{\beta} (\cosh{\beta(\varphi-1)\sin{\beta(\varphi+1)}})\big|_0^1 - \int\limits_0^1 (\sinh{\beta(\varphi-1)\sin{\beta(\varphi+1)}}) d\varphi = \\ = \frac{1}{\beta} (\sin{2\beta}-\cosh{\beta}\sin{\beta}+\sinh{\beta}\cos{\beta}) - \int\limits_0^1 \cosh{\beta(\varphi-1)}\cos{\beta(\varphi+1)} d\varphi$
#
# $ \large \frac{2I_3}{\cos{\beta}\cosh{\beta}} = \frac{1}{\beta} (\frac{\sin{2\beta}}{\cos{\beta}\cosh{\beta}}-\tan{\beta}+\tanh{\beta}) = \frac{2\sin{\beta}}{\beta\cosh{\beta}} $
#
# **Следовательно $\tilde C$ выражается через $\beta$ как:**
#
# $ \large \tilde C = \pm \sqrt{\frac{2}{\frac{1}{\cos^2{\beta}} + \frac{1}{\cosh^2{\beta}} + \frac{1}{\beta}(\frac{\tan{\beta}\cos{3\beta}}{\cos{\beta}} + \tanh{\beta} - \frac{2\sin{\beta}}{\cos{\beta}})}}$
#
# **Тогда $Y_н$ будет иметь вид:**
#
# $ \large Y = \pm \sqrt{\frac{2}{\frac{1}{\cos^2{\beta}} + \frac{1}{\cosh^2{\beta}} + \frac{1}{\beta}(\frac{\tan{\beta}\cos{3\beta}}{\cos{\beta}} + \tanh{\beta} - \frac{2\sin{\beta}}{\cos{\beta}})}} (\frac{1}{\cos{\beta}}\cos{\beta(\varphi+1)} - \frac{1}{\cosh{\beta}}\cosh{\beta(\varphi-1)})$
#
# Знак в данном случае показывает направление деформации стержня.

# %% [markdown]
# **Полиномиальный вид:**
#
# $
# \begin{cases}
# P_1 = A_1 + B_1\varphi + C_1\varphi^2 + D_1\varphi^3 + E_1\varphi^4
# \\
# P_2 = A_2 + B_2\varphi + C_2\varphi^2 + D_2\varphi^3 + E_2\varphi^4 + F_2\varphi^5
# \\
# P_3 = A_3 + B_3\varphi + C_3\varphi^2 + D_3\varphi^3 + E_3\varphi^4 + F_3\varphi^5 + G_3\varphi^6
# \end{cases}
# $
#
# Граничные условия и условия ортонормированности форм:
#
# $P_i\big|_{\varphi=0,1} = P_i'\big|_{\varphi=0} = P_i''\big|_{\varphi=1} = 0$
#
# $\int\limits_0^1 P_iP_j d\varphi =
# \begin{cases}
# 0, i \ne j
# \\
# 1, i = j
# \end{cases}
# $
#
# - Для первой формы используем только граничные условия:
#
# $P_1 = C_1\varphi^2(1-\frac{5}{3}\varphi+\frac{2}{3}\varphi^2)$
#
# Используя условие нормировки $\int\limits_0^1 P_i^2 d\varphi=1$ получим:
#
# $C_1 = \pm\sqrt{\frac{5670}{19}}$ и $P_1 = \pm\sqrt{\frac{5670}{19}}(\frac{2}{3}\varphi^4-\frac{5}{3}\varphi^3 + \varphi^2)$
#
# - Для второй формы деформации используем граничные условия и условие ортонормированности первой и второй формы:
#
# $P_2 = C_2\varphi^2(13-47\varphi+53\varphi^2-19\varphi^3)$
#
# Нормируем:
#
# $C_2 = \pm\sqrt{\frac{6930}{247}}$ и $P_2 = \pm\sqrt{\frac{6930}{247}} (13\varphi^2-47\varphi^3+53\varphi^4-19\varphi^5)$
#
# - Для третьей формы деформации используем граничные условия и условие ортонормированности первой-третьей и второй-третьей форм:
#
# $P_3 = 179.4114811\varphi^2-1077.530522\varphi^3+2241.051202\varphi^4-1950.171057\varphi^5+607.2388964\varphi^6$
#
# **Среднеквадратическое отклонение:**
#
# $\sigma_n = \sqrt{\frac{1}{n}\sum\limits_{i=1}^n(Y_{нj}(x_i)-P_j(x_i))^2}$
#
# $\large x_i = i * \frac{x_n-x_0}{n}$
#
# $\sigma_1 = 0.018558566456215154$
#
# $\sigma_2 = 0.05692057362739215$
#
# $\sigma_3 = 0.12734068522660688$

# %% [markdown]
# ##### Задание форм деформации

# %%
import numpy as np
from matplot import getsolution
from numpy import sqrt, cos, cosh, sin, tan, tanh, pi
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

def p1(phi):
        C1 = sqrt(5670/19)
        return C1 * (phi**2 - 5/3*phi**3 + 2/3*phi**4)

def p2(phi):
        C2 = sqrt(6930/247)
        return C2*(13*phi**2 - 47*phi**3 + 53*phi**4 - 19*phi**5)

def p3(phi):
        return 179.4114811*phi**2-1077.530522*phi**3+2241.051202*phi**4-1950.171057*phi**5+607.2388964*phi**6

def krylov(phi, b):
        return - sqrt(2/(1/cos(b)**2 + 1/cosh(b)**2 + (tan(b)*cos(3*b))/(b*cos(b)) + tanh(b)/b - (2*sin(b))/(b*cosh(b)))) * (1/cos(b)*cos(b*(phi+1)) - 1/cosh(b)*cosh(b*(phi-1)))

# %% [markdown]
# ##### Коэффициенты бета

# %%
beta = np.linspace(0, 11, 1000)
eps = 0.01
for k in range(4):
        beta[(beta > pi/2 + pi * k - eps) & (beta < pi/2 + pi *k + eps)] = np.nan
plt.plot(beta, tan(beta), label='tan(beta)')
plt.plot(beta, tanh(beta), label='tanh(beta)')
plt.ylim(-1, 3)
plt.legend(loc="best")

# %%
def getSolution(a, b):
        eps=0.0001
        x = a
        h = 0.00001
        while x < b:
                if abs(tan(x) - tanh(x)) < eps:
                        break
                x += h
        return round(x, 4)

# %%
beta1 = getsolution(3.5, 4)
beta2 = getSolution(6.5, 7.5)
beta3 = getSolution(10, 11)

print("Коэффициенты найдены с точностью 10^-4\n")
print("Для первой формы деформции:")
print(f"lamda1 = {beta1**4}; beta1 = {beta1};\n Y1 = {- sqrt(2/(1/cos(beta1)**2 + 1/cosh(beta1)**2 + (tan(beta1)*cos(3*beta1))/(beta1*cos(beta1)) + tanh(beta1)/beta1 - (2*sin(beta1))/(beta1*cosh(beta1))))} * ({1/cos(beta1)}*cos({beta1}*(phi+1)) - {1/cosh(beta1)}*cosh({beta1}*(phi-1)))\n")
print("Для второй формы деформции:")
print(f"lamda2 = {beta2**4}; beta2 = {beta2};\n Y2 = {- sqrt(2/(1/cos(beta2)**2 + 1/cosh(beta2)**2 + (tan(beta2)*cos(3*beta2))/(beta2*cos(beta2)) + tanh(beta2)/beta2 - (2*sin(beta2))/(beta2*cosh(beta2))))} * ({1/cos(beta2)}*cos({beta2}*(phi+1)) - {1/cosh(beta2)}*cosh({beta2}*(phi-1)))\n")
print("Для третьей формы деформции:")
print(f"lamda3 = {beta3**4}; beta3 = {beta3};\n Y3 = {- sqrt(2/(1/cos(beta3)**2 + 1/cosh(beta3)**2 + (tan(beta3)*cos(3*beta3))/(beta3*cos(beta3)) + tanh(beta3)/beta3 - (2*sin(beta3))/(beta3*cosh(beta3))))} * ({1/cos(beta3)}*cos({beta3}*(phi+1)) - {1/cosh(beta3)}*cosh({beta3}*(phi-1)))\n")
# Out:
# Коэффициенты найдены с точностью 10^-4
#
# Для первой формы деформции:
# lamda1 = 241.1045062153701; beta1 = 3.9405;
#  Y1 = -0.9877427444495096 * (-1.4337120748956627*cos(3.9405*(phi+1)) - 0.038862301821717356*cosh(3.9405*(phi-1)))
#
# Для второй формы деформции:
# lamda2 = 2496.3705432527104; beta2 = 7.0685;
#  Y2 = -1.0001502806862521 * (1.4140955319294404*cos(7.0685*(phi+1)) - 0.0017030175968382574*cosh(7.0685*(phi-1)))
#
# Для третьей формы деформции:
# lamda3 = 10867.25812396909; beta3 = 10.2101;
#  Y3 = -1.0000623867006382 * (-1.4141059188356153*cos(10.2101*(phi+1)) - 7.359357584202616e-05*cosh(10.2101*(phi-1)))

# %% [markdown]
# ##### Для первой формы деформации

# %%
x = np.linspace(0, 1, 1000)
plt.plot(x, p1(x), label='Полином')
plt.plot(x, krylov(x, beta1), label='Функция Крылова')
plt.legend(loc="best")

# %% [markdown]
# ##### Для второй формы деформации

# %%
plt.plot(x, p2(x), label='Полином')
plt.plot(x, krylov(x, beta2), label='Функция Крылова')
plt.legend(loc="best")

# %% [markdown]
# ##### Для третьей формы деформации

# %%
plt.plot(x, p3(x), label='Полином')
plt.plot(x, krylov(x, beta3), label='Функция Крылова')
plt.legend(loc="best")

# %% [markdown]
# ##### Стандартное отклонение для 1000 узловых точек

# %%
def standartDeviation(n, f1, f2, beta):
        phi = 0
        deviation = 0
        for _ in range(n):
                deviation += (f1(phi, beta) - f2(phi)) ** 2
                phi += 1 / n

        deviation = sqrt(deviation / n)
        return deviation

# %%
print(f"Для первой формы деформации стандартное отклонение = {standartDeviation(1000, krylov, p1, beta1)}\n")
print(f"Для второй формы деформации стандартное отклонение = {standartDeviation(1000, krylov, p2, beta2)}\n")
print(f"Для третьей формы деформации стандартное отклонение = {standartDeviation(1000, krylov, p3, beta3)}\n")
# Out:
# Для первой формы деформации стандартное отклонение = 0.010755055826929302
#
# Для второй формы деформации стандартное отклонение = 0.05697400937598761
#
# Для третьей формы деформации стандартное отклонение = 0.12738558884835777

# %% [markdown]
# #### 3. При заданных граничных условиях найти критическое значение сжимающей нагрузки, при которой происходит потеря устойчивости

# %% [markdown]
# $$EI\frac{\partial ^4 y(x, t)}{\partial x^4} + P\frac{\partial ^2 y(x, t)}{\partial x^2} + m\frac{\partial ^2 y(x, t)}{\partial t^2} = 0$$
#
# $$y(x, t) \bigg|_{x=0} = 0 ; \frac{dy(x, t)}{dx} \bigg|_{x=0} = 0 ; y(x, t) \bigg|_{x=l} = 0;  \frac{d ^2 y(x, t)}{dx^2} \bigg|_{x=l} = 0$$
#
# Переходим к безразмерным переменным:
#
# $ Пусть \ x = \varphi l \ , \ 0 \leq \varphi \leq l \ , \ t = \tau \tilde T$
#
# $\tilde T = l^2\sqrt{\frac{m}{EI}}$
#
# $ \large \frac{\partial ^4 y(\varphi, \tau)}{\partial \varphi^4} + \alpha\frac{\partial ^2 y(\varphi, \tau)}{\partial \varphi^2} + \frac{\partial ^2 y(\varphi, \tau)}{\partial \tau^2} = 0 $
#
# $ \large \alpha = \frac{Pl^2}{EI}$
#
# Пусть $ y(\varphi, \tau) = \sum\limits_{i=1}^nP_i(\varphi)T_i(\tau) $ и в качестве мод используются полиномы
#
# $\sum\limits_{j=1}^nT_j\frac{\partial ^4 P_j}{\partial \varphi^4} + \alpha\sum\limits_{j=1}^nT_j\frac{\partial ^2 P_j}{\partial \varphi^2} + \sum\limits_{j=1}^n\frac{\partial ^2 T_j}{\partial \tau^2}Y_j = 0$
#
# Умножим на полином и проинтегрируем по $\varphi$
#
# $$\sum\limits_{j=1}^n\beta_{ji}T_j + \alpha\sum\limits_{j=1}^n\gamma_{ji}T_j + \frac{\partial ^2 T_j}{\partial \tau^2} = 0$$
#
# $$Где \ \ \beta_{ji} = \int\limits_0^1 \frac{\partial ^4 P_i}{\partial \varphi^4}P_j d\varphi \ ; \ \gamma_{ji} = \int\limits_0^1 \frac{\partial ^2 P_i}{\partial \varphi^2}P_j d\varphi$$

# %% [markdown]
# **Двухмодовое приближение**
#
# $
# \begin{cases}
# (\beta_{11}+\alpha\gamma_{11})T_1 + (\beta_{21}+\alpha\gamma_{21})T_2 + \frac{\partial ^2 T_1}{\partial \tau^2} = 0,
# \\
# (\beta_{12}+\alpha\gamma_{12})T_1 + (\beta_{22}+\alpha\gamma_{22})T_2 + \frac{\partial ^2 T_2}{\partial \tau^2} = 0
# \end{cases}
# $
#
# Характеристическое уравнение ищем в виде:
#
# $$det(Ep^2 + \beta_{ji} + \alpha \gamma_{ji}) = 0$$
#
# Соответственно характеристическое уравнение для двухмодового приближения будет иметь вид:
#
# $p^4 + A_2p^2 + A_4 = 0$ , где
#
# $A_2 = \alpha(\gamma_{11} + \gamma_{22}) + \beta_{11} + \beta_{22}$
#
# $A_4 = \alpha^2(\gamma_{11}\gamma_{22}-\gamma_{21}\gamma_{12}) + \alpha(\beta_{11}\gamma_{22} + \beta_{22}\gamma_{11} - \beta_{21}\gamma_{12} - \beta_{12}\gamma_{21}) + \beta_{11}\beta_{22} - \beta_{21}\beta_{12}$

# %% [markdown]
# \begin{equation*}
# \beta_{ij} = \left(
# \begin{array}{cccc}
# 238.7368 & 24.4007 & 97.1099\\
# 24.4007 & 2574.8016 & 383.0183\\
# 97.1099 & 383.0183 & 11851.8781
# \end{array}
# \right)
# \end{equation*}
#
# \begin{equation*}
# \gamma_{ij} = \left(
# \begin{array}{cccc}
# -11.3684 & 4.3573 & 3.6096\\
# 4.3573 & -41.8623 & 7.9439\\
# 3.6096 & 7.9439 & -91.9925
# \end{array}
# \right)
# \end{equation*}

# %% [markdown]
# ##### Определение коэффициентов бетта, гамма

# %%
gam11 = -216/19
gam21 = gam12 = (9*sqrt(1330)*sqrt(190190))/(32851)
gam13 = gam31 = 3.609602059
gam22 = -10340/247
gam23 = gam32 = 7.943861745
gam33 = -91.99250849

beta11 = 4536/19
beta21 = beta12 = (36*sqrt(1330)*sqrt(190190))/(23465)
beta13 = beta31 = 97.10996
beta22 = 635976/247
beta23 = beta32 = 383.0182633
beta33 = 11851.87805

# %%
print(f"A2 = a * {gam11+gam22} + {beta11+beta22}")
print(f"A4 = a^2 * {gam11*gam22-gam21*gam12} + a * {beta11*gam22+beta22*gam11-beta21*gam12-beta12*gam21} + {beta11*beta22-beta21*beta12}")
# Out:
# A2 = a * -53.230769230769226 + 2813.538461538462
# A4 = a^2 * 456.9230769230769 + a * -39478.15384615385 + 614104.6153846154

# %% [markdown]
# Пусть $\tilde p = p^2$
#
# $\tilde p^2 + A_2\tilde p + A_4 = 0$
#
# Дискриминант будет иметь вид:
#
# $D = A_2^2 - 4A_4 $ , рассмотрим его знак

# %%
def A2(a):
        return a * (gam11+gam22) + beta11+beta22

def A4(a):
        return a**2*(gam11*gam22-gam21*gam12) + a*(beta11*gam22+beta22*gam11-beta21*gam12-beta12*gam21) + beta11*beta22-beta21*beta12

def Discriminant(a):
        return A2(a)**2 - 4*A4(a)

# %%
a = np.linspace(70.35, 70.45, 10000)

plt.plot(a, Discriminant(a), label='Дискриминант')
plt.legend(loc="best")

# %% [markdown]
# Так как дискриминант всегда больше нуля, то
#
# $p = \sqrt{-A_2 \pm \sqrt{A_2^2 - 4A_4}}$
#
# Исследование на знакопостоянство $p$ равнозначно исследованию $A_4$
#
# Найдём такое $\alpha$ , где $A_4$ становится отрицательным

# %%
a = np.linspace(15, 45, 10000)

plt.plot(a, A4(a), label='A_4')
plt.legend(loc="best")

# %%
def getAlpha(a, b):
        eps=0.00001
        x = a
        h = 0.00001
        while x < b:
                if A4(x) < eps:
                        break
                x += h
        return x

# %%
print(f"Численное решение = {getAlpha(19.5, 21)}\n")
print(f"Решение, полученное из Maple = {216/5 - 16*sqrt(51)/5}")
# Out:
# Численное решение = 20.34742999996792
#
# Решение, полученное из Maple = 20.34742902866288

# %% [markdown]
# Получили значение $\alpha = 20.34742902866288$ , соответствующее потере устойчивости, значит критическое значение сжимающей нагрузки, полученное двухмодовым приближением:
#
# $$P_{кр} = 20.34742902866288\cdot\frac{EI}{l^2}$$

# %% [markdown]
# **Трёхмодовое приближение**
#
# $
# \begin{cases}
# (\beta_{11}+\alpha\gamma_{11})T_1 + (\beta_{21}+\alpha\gamma_{21})T_2 + (\beta_{31}+\alpha\gamma_{31})T_3 + \frac{\partial ^2 T_1}{\partial \tau^2} = 0,
# \\
# (\beta_{12}+\alpha\gamma_{12})T_1 + (\beta_{22}+\alpha\gamma_{22})T_2 + (\beta_{32}+\alpha\gamma_{32})T_3 + \frac{\partial ^2 T_2}{\partial \tau^2} = 0,
# \\
# (\beta_{13}+\alpha\gamma_{13})T_1 + (\beta_{23}+\alpha\gamma_{23})T_2 + (\beta_{33}+\alpha\gamma_{33})T_3 + \frac{\partial ^2 T_3}{\partial \tau^2} = 0,
# \end{cases}
# $
#
# Характеристическое уравнение ищем в виде:
#
# $$det(Ep^2 + \beta_{ji} + \alpha \gamma_{ji}) = 0$$
#
# Соответственно характеристическое уравнение для трёхмодового приближения будет иметь вид:
#
# $p^6 + bp^4 + cp^2 + d = 0$ , где
#
# $b = 14665.41651 - 145.2232778 \alpha$
#
# $c = 33803686.15 - 935973.5410 \alpha + 5277.62093 \alpha^2$
#
# $d = -40520.78089 \alpha^3 + 9117175.955 \alpha^2 - 525149344.1 \alpha + 7220803524$
#
# Условия существования трёх действительных корней:
#
# $p = \frac{c}{2} - \frac{b^2}{3}$
#
# $q = d - \frac{bc}{3}$
#
# $D =  \frac{q}{4}^2 + \frac{p}{9} ^ 3 > 0$
#
# По данным Maple, $D > 0$ при $\alpha \in (-\inf,1.215464761), (72.21491524, \inf)$, в чём можно убедиться на графике.
#
# Следовательно, три действительных корня существуют пока $\alpha < 72.21491524$

# %%
def B(a):
        return -145.2232777*a + 14665.41651

def C(a):
        return 3.380368615*(10**7) - 935973.5410*a + 5277.62093*(a**2)

def D(a):
        return -40520.78089*(a**3) + 9.117175955*(10**6)*(a**2) - 5.251493441*(10**8)*a + 7.220803524*(10**9)

def P(a):
        return C(a)/2 - (B(a)**2) / 3

def Q(a):
        return D(a) - (B(a) * C(a)) / 3

def Discriminant2(a):
        return (Q(a)/2)**2 + (P(a)/3)**3

# %%
a = np.linspace(0, 80, 10000)

plt.plot(a, Discriminant2(a), label='Дискриминант 2')
plt.legend(loc="best")

# %% [markdown]
# Рассмотрим систему:
#
# $
# \begin{cases}
# b > 0,
# \\
# c > 0,
# \\
# d > 0
# \end{cases}
# $
#
# Следовательно, все корни отрицательны, пока $\alpha < 20.19501306$
#
# Получили значение $\alpha = 20.19501307$ , соответствующее потере устойчивости, значит критическое значение сжимающей нагрузки, полученное трёхмодовым приближением:
#
# $$P_{кр} = 20.19501307\cdot\frac{EI}{l^2}$$
#
# Что незначительно меньше значения, полученного двухмодовым приближением.
